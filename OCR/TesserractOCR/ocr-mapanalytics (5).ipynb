# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 81 not upgraded.
# Requirement already satisfied: pytesseract in /opt/conda/lib/python3.10/site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.10/site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from pytesseract) (9.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21.3->pytesseract) (3.0.9)

# %%
import cv2
import numpy as np
import cv2
import os
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
map_data = {}

def add_map(map_id, value_id, color, lower_bound, upper_bound):
    map_data[map_id][value_id] = {
        "color": color,
        "lower_bound": lower_bound,
        "upper_bound": upper_bound
    }

# %%
image_files = [f for f in os.listdir(path="/kaggle/input/dv-pe/accuracy_images") if f.endswith(('.png'))]

map_data_path = "/kaggle/working/map_data.txt"
os.mkdir("/kaggle/working/masked_images")

def num_there(s):
    return any(i.isdigit() for i in s)

# %%
def mask(image):
    x, y, w, h = 188, 17, 283, 32

    x = x - (w//2)
    y = y - (h//2)

    # Create a mask
    mask = np.ones_like(image) * 255  # White mask

    # Draw a black rectangle on the mask to cover the region outside the bounding box
    cv2.rectangle(mask, (x, y), (x + w, y + h), (0, 0, 0), thickness=cv2.FILLED)

    # Bitwise AND operation to apply the mask
    image = cv2.bitwise_and(image, mask)

    # Display the original image and the masked image using matplotlib
    plt.figure(figsize=(10, 5))

    # plt.subplot(1, 2, 1)
    # plt.imshow(cv2.cvtColor(images, cv2.COLOR_BGR2RGB))
    # plt.title("Original Image")
    # plt.axis("off")

#     plt.subplot(1, 2, 2)
#     plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#     plt.title("Masked Image")
#     plt.axis("off")

#     plt.show()
    
    return image

# %%
for image in image_files:
    image_dir = "/kaggle/input/dv-pe/accuracy_images"
    image_path = os.path.join(image_dir, image)
    # Argument Parser
    args = {"image": image_path, "pre_processor": "thresh"}  # Replace with your image path

    # print(map_name)
    # Reading the image with text
    images = cv2.imread(args["image"])
    image_rgb = cv2.cvtColor(images, cv2.COLOR_BGR2RGB)

    # Converting to grayscale image
    gray = cv2.cvtColor(images, cv2.COLOR_BGR2GRAY)

    # performing preprocessing techniques of threshing and/or blurring.
    if args["pre_processor"] == "thresh":
        gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
    if args["pre_processor"] == "blur":
        gray = cv2.medianBlur(gray, 3)

    # adding image to memory
    # filename = "{}.png".format(os.getpid())
    # cv2.imwrite(filename, gray)
    # text = pytesseract.image_to_string(Image.open(filename))
    # print(text)

    images = mask(images)
    
    # plt.subplot(1, 2, 2)
    # plt.imshow(cv2.cvtColor(images, cv2.COLOR_BGR2RGB))
    # plt.title("Masked Image")
    # plt.axis("off")

    # plt.show()

    filename = "{}.png".format(os.getpid())
    # print(filename)
    cv2.imwrite(filename, gray)

    data = pytesseract.image_to_data(Image.open(filename), output_type=pytesseract.Output.DICT)

    # Looping over the detected text and the bounding boxes
    for i in range(len(data["text"])):
        value_id = 0
        if data["text"][i].strip() != "":
            x, y, w, h = data["left"][i], data["top"][i], data["width"][i], data["height"][i]
            # cv2.rectangle(images, (x, y), (x + w, y + h), (0, 255, 0), 2)

            text = data["text"][i]
            # print(f"Text: {text}, Bounding Box: {x}, {y}, {w}, {h}")

            if num_there(text)==1:
                value_id += 1
                # print(type(text))
                # print(f"Text: {text}, Bounding Box: {x}, {y}, {w}, {h}")
                # cv2.rectangle(images, (x, y), (x + w, y + h), (0, 255, 0), 2)

                x1 = x
                x2 = x
                y1 = y + h // 2
                y2 = y + h // 2 - 1

                while all(images[y1, x1]==images[y2, x2]):
                    x2-=1
                x2-=2

                color = images[y2,x2]
                # print(color)
                # cv2.rectangle(images, (x2, y2), (x2+5, y2+5), (0, 255, 0), 2)

                values = text.split("-")
                # print(values)

                if len(values)==1:
                    lower_bound = values[0]
                    upper_bound = values[0]
                else:
                    lower_bound = values[0]
                    upper_bound = values[1]

                blue, green, red = color
                # print(f"Blue: {blue}, Green: {green}, Red: {red}")

                # add_map(map_id, value_id, (blue, green, red), lower_bound, upper_bound)
                # print(map_data)

                map_name = "map_"+image[4:-4]
                if map_name in map_data:
                    map_data[map_name][value_id] = {
                        "color": (blue, green, red),
                        "lower_bound": lower_bound,
                        "upper_bound": upper_bound,
                    }
                else:
                    map_data[map_name] = {
                        value_id: {
                            "color": (blue, green, red),
                            "lower_bound": lower_bound,
                            "upper_bound": upper_bound,
                        }
                    }

                with open(map_data_path, 'a') as f2:
                    f2.write(map_name+":")
                    f2.write(str(value_id)+":(")
                    f2.write(str(blue)+","+str(green)+","+str(red)+"),")
                    f2.write(str(lower_bound)+",")
                    f2.write(str(upper_bound))
                    f2.write("\n---------------------\n")
                # print(map_data)
                
                processed_image_path = f"/kaggle/working/masked_images/{image[:-4]}_processed.png"
                cv2.imwrite(processed_image_path, images)

                # color = images[y,x-25] # have to edit this to get the exact colour.
                # print(f'Color at ({x}, {y}): {color}')

os.remove(filename)
# plt.imshow(cv2.cvtColor(images, cv2.COLOR_BGR2RGB))
# Out:
# /tmp/ipykernel_27/2383781749.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 5))

# %%
# !zip -r annotated.zip /kaggle/working/masked_images
# Out:
#   adding: kaggle/working/masked_images/ (stored 0%)
#   adding: kaggle/working/masked_images/map_466_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_346_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_399_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_395_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_294_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_440_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_282_processed.png (deflated 10%)
#   adding: kaggle/working/masked_images/map_302_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_391_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_427_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_384_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_439_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_351_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_409_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_435_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_273_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_316_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_408_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_337_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_448_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_289_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_303_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_265_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_297_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_434_processed.png (deflated 10%)
#   adding: kaggle/working/masked_images/map_357_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_363_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_419_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_288_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_402_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_405_processed.png (deflated 11%)
#   adding: kaggle/working/masked_images/map_287_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_293_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_449_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_403_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_278_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_318_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_299_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_306_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_284_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_338_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_451_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_415_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_430_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_358_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_459_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_269_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_444_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_313_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_420_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_320_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_410_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_319_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_341_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_412_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_385_processed.png (deflated 10%)
#   adding: kaggle/working/masked_images/map_374_processed.png (deflated 13%)
#   adding: kaggle/working/masked_images/map_329_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_322_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_400_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_295_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_339_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_443_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_383_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_349_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_279_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_342_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_381_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_310_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_377_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_345_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_396_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_336_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_370_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_271_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_340_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_324_processed.png (deflated 11%)
#   adding: kaggle/working/masked_images/map_348_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_375_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_335_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_406_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_422_processed.png (deflated 10%)
#   adding: kaggle/working/masked_images/map_281_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_417_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_423_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_462_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_352_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_355_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_280_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_441_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_447_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_367_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_437_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_389_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_298_processed.png (deflated 10%)
#   adding: kaggle/working/masked_images/map_276_processed.png (deflated 11%)
#   adding: kaggle/working/masked_images/map_368_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_267_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_277_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_314_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_407_processed.png (deflated 7%)
#   adding: kaggle/working/masked_images/map_386_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_366_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_311_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_309_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_315_processed.png (deflated 9%)
#   adding: kaggle/working/masked_images/map_292_processed.png (deflated 11%)
#   adding: kaggle/working/masked_images/map_308_processed.png (deflated 11%)
#   adding: kaggle/working/masked_images/map_373_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_426_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_290_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_376_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_325_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_432_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_465_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_387_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_268_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_388_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_436_processed.png (deflated 5%)
#   adding: kaggle/working/masked_images/map_452_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_270_processed.png (deflated 8%)
#   adding: kaggle/working/masked_images/map_350_processed.png (deflated 10%)
#   adding: kaggle/working/masked_images/map_327_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_418_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_317_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_364_processed.png (deflated 4%)
#   adding: kaggle/working/masked_images/map_425_processed.png (deflated 6%)
#   adding: kaggle/working/masked_images/map_378_processed.png (deflated 4%)
